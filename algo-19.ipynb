# %%
import simpy
import numpy as np
import random
import pandas as pd
import networkx as nx

# Constants and Simulation Parameters
KB_TO_MB = 1 / 1024
BIT_TO_MBIT = 1 / 1024
GHZ_TO_HZ = 1e9
MHZ_TO_HZ = 1e6
ENV_RUN_TIME = 1000  # simulation run time
LC = 1e-24  # power usage constant
Y_NT = 0.5  # Weighted factor for local time cost
Y_NE = 0.5  # Weighted factor for energy cost

# Networking and Computational Parameters
transmission_rate = [500, 1000, 1500, 2000, 2500, 3000]  # in kb/s
num_devices_list = [50, 100, 150, 200, 250, 300]
task_data_sizes = [5, 10, 15, 20, 25, 30, 35, 40, 45]  # task data in Mbit
max_power_consumption = 1000  # in Joules

# CPU and power parameters for devices and MEC server
local_device_cycle_freq = random.uniform(2, 4) * MHZ_TO_HZ  # in Hz
mec_server_cycle_freq = 4 * GHZ_TO_HZ  # MEC server capacity set to 4 GHz
local_device_power = random.uniform(100, 400) / 1000  # in Watts
clock_cycles_per_bit = random.randint(800, 1200)

# Channel parameters
B = 1e6  # Channel bandwidth in Hz
H0 = 1e-9  # Noise spectral density in W/Hz
P = 1e-3  # Communication capacity in W
alpha = 4  # Path loss exponent

class MECServer:
    def __init__(self, env, capacity):
        self.env = env
        self.capacity = capacity
        self.processor = simpy.Resource(env, capacity=int(capacity))
        self.dag = nx.DiGraph()

    def add_task_to_dag(self, task_id, dependencies, task_data):
        self.dag.add_node(task_id, data=task_data, vk=random.random())
        for dep in dependencies:
            self.dag.add_edge(dep, task_id)
        print(f"Added task {task_id} to DAG with dependencies {dependencies} and data {task_data}")

    def process_task(self, task_id):
        task_info = self.dag.nodes[task_id]
        data_bits = task_info['data'] * BIT_TO_MBIT * 1e6
        clock_cycles = data_bits * clock_cycles_per_bit

        edge_time = clock_cycles / self.capacity
        print(f"Processing task {task_id} with edge time {edge_time}")

        yield self.env.timeout(edge_time)
        self.dag.nodes[task_id]['ct'] = self.env.now

    def execute_tasks(self):
        for task in nx.topological_sort(self.dag):
            yield self.env.process(self.process_task(task))

class Device:
    def __init__(self, env, mec_servers, logs, num_devices):
        self.env = env
        self.mec_servers = mec_servers
        self.logs = logs
        self.num_devices = num_devices
        self.Q0 = []
        self.Q1 = []

    def local_computation_model(self, task_data):
        Hn = task_data * BIT_TO_MBIT * 1e6  # Convert Mbit to bits
        Rn = clock_cycles_per_bit  # CPU cycles per bit
        Qn = 0  # No offloading, process locally
        local_cycles = Hn * Rn * (1 - Qn)
        RTl = local_cycles / local_device_cycle_freq
        ATl = LC * local_device_cycle_freq**2 * local_cycles
        DTl = Y_NT * RTl + Y_NE * ATl
        print(f"Local computation model: RTl={RTl}, ATl={ATl}, DTl={DTl}")
        return RTl, ATl, DTl

    def mec_computation_model(self, task_data, Qn):
        mec = min(self.mec_servers, key=lambda x: len(x.dag))
        task_id = self.env.now
        mec.add_task_to_dag(task_id, [], task_data)

        # Calculate the local computation parameters
        Hn = task_data * BIT_TO_MBIT * 1e6  # Convert Mbit to bits
        Rn = clock_cycles_per_bit  # CPU cycles per bit

        # Calculate transmission rate and time
        RQx = local_device_power  # Assuming transmission power is the same as device power
        distance = random.uniform(10, 100)  # Distance between device and MEC server in meters
        DV_x_m = (distance**-alpha)  # Channel gain
        Wx = B * np.log2(1 + (RQx * DV_x_m) / (H0 * P))
        if Wx <= 0:
            Wx = 1e-9  # Avoid divide by zero
        transmission_time = (Hn * Qn) / Wx
        print(f"MEC computation model: transmission_time={transmission_time}, Wx={Wx}")

        # Calculate energy consumption for transmission
        transmission_energy = RQx * transmission_time

        # Process task on MEC server
        edge_time = Hn * Rn * Qn / mec.capacity
        yield self.env.timeout(transmission_time)
        yield self.env.process(mec.execute_tasks())
        if 'ct' in mec.dag.nodes[task_id]:
            ct = mec.dag.nodes[task_id]['ct']
        else:
            ct = self.env.now

        # Calculate edge computation parameters
        ATm = LC * mec.capacity**2 * (Hn * Rn * Qn)
        DTm = transmission_energy + ATm
        print(f"MEC computation model: edge_time={edge_time}, ATm={ATm}, DTm={DTm}")

        return transmission_time + edge_time, DTm, Wx

    def send_task(self, task_data, dependencies=[]):
        Qn = random.uniform(0, 1)  # Offloading decision
        if Qn == 0:  # Local computation
            RTl, ATl, DTl = self.local_computation_model(task_data)
            yield self.env.timeout(RTl)
            total_time = RTl
            energy_consumed = ATl
            trans_rate = 0
        else:  # MEC computation
            RTm, DTm, trans_rate = yield self.env.process(self.mec_computation_model(task_data, Qn))
            total_time = RTm
            energy_consumed = DTm
        print(f"Task {self.env.now}: total_time={total_time}, energy_consumed={energy_consumed}, Qn={Qn}, trans_rate={trans_rate}")

        self.logs.append({
            'num_devices': self.num_devices,
            'task_data': task_data,
            'completion_time': total_time,
            'energy_consumed': energy_consumed,
            'weighted_waste': DTl if Qn == 0 else DTm,
            'transmission_rate': trans_rate  # Log the actual transmission rate
        })

env = simpy.Environment()
mecs = [MECServer(env, mec_server_cycle_freq) for _ in range(10)]  # Number of MEC servers set to 10
logs = []

for num_devices in num_devices_list:
    devices = [Device(env, mecs, logs, num_devices) for _ in range(num_devices)]
    for device in devices:
        task_size = random.choice(task_data_sizes)
        env.process(device.send_task(task_size))

env.run(until=ENV_RUN_TIME)

df_logs = pd.DataFrame(logs)
print(df_logs.head())
if df_logs.empty:
    print("No logs were generated.")
else:
    if df_logs['energy_consumed'].max() > max_power_consumption:
        print("Warning: Power consumption exceeded the maximum limit.")
# Out:
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0016622194628039737, Wx=12302091.570942068
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00027580129572523174, Wx=13224493.116000144
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.00037751677975062355, Wx=21444805.027486682
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.000692381267016856, Wx=13043419.013781112
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0010272762559650583, Wx=15991237.504096795
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0009605290183426682, Wx=17029658.946859263
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0006478320939724185, Wx=13843507.869439881
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.00034896375809079954, Wx=13670393.80056328
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00010606331241366249, Wx=12220529.674768314
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0013971568385514875, Wx=13208919.016326357
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0005797113217034149, Wx=13088515.294387838
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.00016623276827808643, Wx=13099301.4313434
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.001212325218735602, Wx=17186287.131629758
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0011415076051594854, Wx=16086419.27714881
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.00028694690911340104, Wx=15455793.69315584
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=6.91833734560106e-05, Wx=12050422.120552499
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0009261775856235512, Wx=13267077.035662219
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0006287341626468211, Wx=24245449.590864904
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0005230468042805506, Wx=17326118.74816782
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0006833510680277913, Wx=14712172.10073795
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.00010256493842663932, Wx=23245555.943461176
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=4.1188890444210844e-05, Wx=18797285.649923347
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.00019204047864927713, Wx=15714692.61269664
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0009378160266882185, Wx=20518309.012009338
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0001675936617752994, Wx=11973674.521831319
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.00027303444986549074, Wx=14050002.662493004
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.0002807570953359002, Wx=12904316.539328761
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0025841531784662024, Wx=13848834.620084029
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.00029826805519884275, Wx=12348353.946536902
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.000829665600042337, Wx=12632621.670647688
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00015516549263184254, Wx=20665133.323101323
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0005953532330803688, Wx=13066013.539587518
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0005642923902656288, Wx=17543880.24845098
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0011357553999075283, Wx=14998789.0961766
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0012495631183106026, Wx=12384345.326762794
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=3.599680067281583e-05, Wx=17010588.873260256
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0006505327757488926, Wx=12272276.398484483
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0010414861486427787, Wx=12547365.83475083
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.00020784871753827801, Wx=14337498.720633594
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.001971155284149736, Wx=12121088.537015097
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.00023307402550090076, Wx=19944151.090044342
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.000548943352996127, Wx=20667181.372824233
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=5.7411206567138594e-05, Wx=18175157.85662186
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=1.3447073935474584e-05, Wx=22357223.205450524
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.00028619278894494437, Wx=25031351.298611104
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0002782963577744821, Wx=12397909.911694692
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0011009307123883616, Wx=16742401.20055995
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.00042851210271116513, Wx=12882951.957484126
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=5.70958017718121e-05, Wx=17033970.505562022
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.000169085163529108, Wx=21608369.877318885
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0004520172116049406, Wx=21355234.619810373
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.0001382427242408902, Wx=12788217.988651844
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.00010504662213737776, Wx=24631161.788077928
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0017037975459189255, Wx=13503737.89222769
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0021433584325872388, Wx=12269323.51422259
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0011324916607874734, Wx=21739208.451965343
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0008173749746485261, Wx=22199464.4378975
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0013254177889052087, Wx=17465287.201873828
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.001155504620980225, Wx=17452258.04401688
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=7.269583258187181e-05, Wx=19360195.101937063
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00015077914731555505, Wx=12947907.423209677
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00020220734507103325, Wx=17946962.591930445
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.00028192138693050107, Wx=12078372.136210797
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0004047313750857862, Wx=17847045.108283587
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.0001831225374567697, Wx=17802202.97828237
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0009123027496907854, Wx=12298979.553193199
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0009520341462021637, Wx=21032223.011253465
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0003588058155728631, Wx=13451381.326609839
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0004438370061023046, Wx=17879947.65134806
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.00043278595406716895, Wx=12422468.173223328
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0006815360287435699, Wx=12055592.195676208
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.00045296849947695653, Wx=15292673.292551557
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=6.0647338249893275e-05, Wx=12497851.668268763
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0004505342490260586, Wx=13560697.703643296
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=5.339572868497374e-06, Wx=23151152.609904148
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.000500961467812971, Wx=13121464.046622694
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.001975953270590117, Wx=12299458.372109087
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.001723856146970261, Wx=14628103.948390273
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.001975577058532648, Wx=13785803.216434775
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0020637739165799153, Wx=12708279.1782439
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.00028763360891417855, Wx=18281882.013030294
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.00015779504407303005, Wx=17901581.42974519
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=1.7292170510875926e-05, Wx=14829375.349918827
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=8.622767089389407e-05, Wx=15699449.637503209
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.00023977222980984278, Wx=13239227.383585103
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0030051539515891343, Wx=13858192.559701238
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0010895794185625293, Wx=15133293.584039126
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.002456130028994732, Wx=13512127.466315327
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0017992494487195064, Wx=15945969.283670604
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.002270676305999562, Wx=14243872.135690745
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00023389556847386986, Wx=13312630.84361027
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0009159540222154212, Wx=13178246.534620693
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0006424492706374727, Wx=16174902.037487578
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0003393356873047527, Wx=16919445.10492908
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.000571931815098609, Wx=13328115.493622612
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0007619313533095396, Wx=15146939.340981523
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0007489898657145711, Wx=12263160.355014663
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0014927728649138164, Wx=12569721.283912959
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=9.414876279106037e-05, Wx=17639834.286144488
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0019789735839875738, Wx=14644445.102784215
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.00028821970346851384, Wx=17861008.394088276
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0008324005912906204, Wx=15476571.3291377
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.00035991416148237155, Wx=17679084.08771666
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0004718017970350165, Wx=15423079.371816345
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0013137385448351532, Wx=17343608.000867125
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0019726990790901, Wx=13049728.313356826
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0025844962909577604, Wx=12246391.728760155
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0006599347898336252, Wx=13836583.559833905
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0013363149660048622, Wx=23000213.115690924
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0005693036380108689, Wx=12315462.239202386
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0003056119748658461, Wx=24064883.109772947
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00015387890903803493, Wx=12804551.522865387
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0006349523477217495, Wx=16421268.529873434
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0006952764117573822, Wx=12582451.74766075
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.002304234975883952, Wx=12821242.602692414
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0014321755237672856, Wx=14262606.738802422
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.00026885097069598285, Wx=12545015.803210195
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0008795355372667004, Wx=12290035.753673948
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=8.288142089589731e-05, Wx=14094218.916700969
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0009178477318228101, Wx=13464085.741506433
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0005341837291246403, Wx=14327833.282846002
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00031819648259382707, Wx=12199722.989489298
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0002387879932306288, Wx=13497933.02228041
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0010796873749114111, Wx=17313523.793586113
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0001989344644756942, Wx=17957450.809956085
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0011293428977676026, Wx=11942450.169997953
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0005824844784813756, Wx=14845802.817559293
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00029194961268146086, Wx=14960223.296457207
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0004618217688950104, Wx=12736636.211687751
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0007369346177427144, Wx=24224605.839023914
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.00017997919823818445, Wx=16988724.96678387
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0005286654929303175, Wx=17182305.793878797
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0017469123324148385, Wx=18058009.272604547
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=7.00423856523517e-05, Wx=12562875.81357934
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.00017290946016559753, Wx=14890899.562421275
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0019876736459506915, Wx=12555594.824674485
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0006263702018129298, Wx=16472870.780816346
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.001282425658056628, Wx=13953013.710092263
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0010635336417175705, Wx=19307728.393541485
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0027748658097774114, Wx=13438926.345902741
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0011190714474819201, Wx=14248066.112841114
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.001258429419098745, Wx=14894473.55458021
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.002977684777659766, Wx=12131371.693529008
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0007632206297300788, Wx=12776624.546773473
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0020336064283926945, Wx=15185799.334976722
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.001475177050984398, Wx=21118094.170602374
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.00016744676104063432, Wx=13466046.665222423
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0020060241413574474, Wx=16793827.84371545
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0007955758752580458, Wx=21657635.352021657
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.00025632396307962953, Wx=12765749.447850367
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0008145229492707422, Wx=13598215.65973033
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=7.928483625073331e-05, Wx=16419797.45726535
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0024030548275927634, Wx=12032018.538846979
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0010351627048272153, Wx=23922784.465631165
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.002466329329549758, Wx=13079464.355160033
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0011000009011931252, Wx=20199588.763772737
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0012624470833020119, Wx=16400843.370759944
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0015998078741116274, Wx=18100400.59662151
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0024186481145227223, Wx=13822946.019220322
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00019769074618592169, Wx=15751967.14811638
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00019586929264523527, Wx=18922204.628413044
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0018088849836416397, Wx=13492523.47162744
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0006042863962892988, Wx=21684063.855645824
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=6.328612898516274e-05, Wx=19231220.111973785
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0003370993759531858, Wx=17442654.411640354
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0017005616703075104, Wx=14223117.791276135
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=4.165302445416347e-05, Wx=13754175.25062427
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.002029913432035772, Wx=18564814.64950704
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0015387755948480441, Wx=17306311.12097417
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=6.720519461298423e-06, Wx=18079584.725551117
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0017408269723420539, Wx=13232006.760246335
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0006395215435123839, Wx=22440974.501064055
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0010618540309326643, Wx=13190007.912911823
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=8.951782204472592e-06, Wx=14512955.707268687
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0019494499931669413, Wx=15115633.560909078
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.001344118027982678, Wx=12481952.877373153
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0014603502526433004, Wx=12513557.896748662
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.00015798849544052502, Wx=13529281.17161229
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0015772572047475265, Wx=14700999.49547834
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.000736487458192472, Wx=21206452.2600598
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00010011619720312564, Wx=21331552.056482133
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0013880547755935498, Wx=12899249.188240007
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.002339234250111157, Wx=16534191.854040649
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0008694184549978125, Wx=15656208.988829717
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0010616539273179068, Wx=13490763.492040396
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.000990911673614402, Wx=14458663.84039918
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.00013358100015466287, Wx=13799606.404487796
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0004117745935199309, Wx=12218913.934370803
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.00032095252376745015, Wx=12261710.611444399
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0020083751045892636, Wx=14176577.0213902
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0007919492196892388, Wx=12428761.846368833
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0012642225134557306, Wx=14394896.088908777
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.00021476548300114064, Wx=11973070.322553298
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.002739885975219465, Wx=13704421.327543642
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.00164700133877428, Wx=19061768.845626306
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.00020419008971570956, Wx=14335096.24508048
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0006936639173566911, Wx=16848226.201664332
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0013270055980076879, Wx=21387075.61462015
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0007975811481321309, Wx=13738275.95182951
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0005790056107040502, Wx=18485116.67154003
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0014440083756730028, Wx=18130756.674771614
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0012148502645049973, Wx=14264200.101502182
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0003903540678157964, Wx=19800034.022222318
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0006916604455663137, Wx=14092176.966299977
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=4.597586310116528e-05, Wx=16558200.339687627
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0008831160438451668, Wx=16061002.230722615
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.0001603859022059014, Wx=20885143.423310008
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00030029969330442127, Wx=13927165.988541188
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0005342237564338836, Wx=15042126.763493886
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0004778887452262253, Wx=22731405.78620863
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.000625709229427918, Wx=21418375.921307553
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0005771138552247372, Wx=14455016.907123929
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.00044976965503314733, Wx=20597107.889134794
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0001512748988220939, Wx=16241663.422829475
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0008929789760547232, Wx=15359348.455671165
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0004011010563073463, Wx=14174576.646442747
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0015427338902623958, Wx=14727508.091830632
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.001799631573548258, Wx=13404792.389692998
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.001192599555580606, Wx=21817315.859865185
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0010615908482783168, Wx=12580420.698476931
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0006460337733063031, Wx=13009285.781462008
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0029340366259484234, Wx=12121539.14049338
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0004060722484710277, Wx=18504111.019254215
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0008419981618682216, Wx=14615968.582849603
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0007122912105497174, Wx=14123796.75646796
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.002005650939713681, Wx=15081072.883194026
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0007921237087512187, Wx=13758820.105717825
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0005639838481499113, Wx=11932449.891815232
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0021363045183050502, Wx=15171088.820275288
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.00040026968338608803, Wx=21430559.48649952
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0027506909723538694, Wx=13351659.514798071
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0006404264019182448, Wx=18036876.46834321
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.001096590808284092, Wx=16513067.819413226
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0008538177413791111, Wx=22712810.17923459
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.00044966113361272366, Wx=12432138.376386195
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.00026870544221828716, Wx=13541886.712621802
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=4.9894810901560594e-05, Wx=19978746.186432194
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0011013874157415962, Wx=12689816.906990862
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00013402428383128072, Wx=23771387.540800445
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.00019220820371500382, Wx=17741867.541300565
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.00021243904130410164, Wx=21399250.533967588
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0014314063662294288, Wx=21536357.517152987
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0005757307156014844, Wx=15679738.787434848
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0011450646494890937, Wx=14956935.419739509
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0011143773653787149, Wx=21305691.021991912
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0012654538683692404, Wx=16768701.003746394
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0011147306167286724, Wx=21123615.2715795
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=2.2835327773552133e-05, Wx=14220510.232790982
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0013371219295533452, Wx=15321886.751699092
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.00024297794816126764, Wx=13727552.108784012
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0004065831868781852, Wx=12684396.467184477
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0004232902915747077, Wx=17712333.101067152
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.00017737833598107617, Wx=12230851.289036047
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.001779418740490636, Wx=13187454.751049532
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0016952769683534583, Wx=15151806.339431291
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.00048479891142089946, Wx=11957749.587467227
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.000664123276049708, Wx=17192969.912418038
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0007702666833624519, Wx=23169970.16185014
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0011501080780715919, Wx=19675258.929942276
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0013897941542612103, Wx=14787982.152519435
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00033035074448544127, Wx=12478763.983879775
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.00017225430529258358, Wx=16015509.536237972
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=9.238093410128508e-05, Wx=15686996.924837064
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=2.6296283025411566e-05, Wx=13644107.844550535
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.0002655069071354951, Wx=17241427.42250981
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0001809888783981708, Wx=18314828.26945278
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.00020914517847759196, Wx=23100084.23366216
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.00204586314967417, Wx=14065512.494215634
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0005825199566601423, Wx=12617953.861592837
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0003435378269301077, Wx=13761705.47853436
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0015838718066922323, Wx=19839446.289625436
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0005198535370470488, Wx=12241563.76598947
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0018919589119827432, Wx=19072054.96017978
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0003276951111636795, Wx=12670259.875833338
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0005003325500122894, Wx=17930597.189809874
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=3.643348864360653e-05, Wx=12301160.28117529
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.00039932657461077067, Wx=12412100.65901701
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0011398068431903506, Wx=20897515.29039659
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0006560900243233184, Wx=16528412.065347947
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0003126933785951206, Wx=22791597.236858096
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0008079829946733633, Wx=18312280.5472861
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0001276607706593647, Wx=13659767.56026581
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0005578154888134844, Wx=18697079.79098562
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0004544363211374468, Wx=21503961.065958384
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00026252646199854474, Wx=14641356.524662802
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00013728760977578769, Wx=24411833.87679065
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0007041614059472432, Wx=13944280.888807192
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0014542743650131631, Wx=14419036.667460123
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00017675836620251908, Wx=16520378.864977
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0017924872137839046, Wx=13892859.581998965
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0010457657213492754, Wx=14318822.012833783
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.001500361653099642, Wx=14231602.00729598
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.0002433357554991951, Wx=12465549.537184866
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.00010841692999512919, Wx=18803531.476969205
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0009129427380218435, Wx=21964130.099201098
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0007335684514299599, Wx=15171606.90365077
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0004350221641816749, Wx=14110860.052365493
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0009572678080234614, Wx=22514504.346790098
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.00234123051649654, Wx=13063945.733702628
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0005789934263749062, Wx=12320062.383458806
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.000261165478191967, Wx=15059498.251432713
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00019950718666656228, Wx=14706032.39547601
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.00036817602079538457, Wx=18833366.834147956
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.000121526705830331, Wx=19584403.98917564
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.002522467698959952, Wx=15225059.451808337
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0018647574337268965, Wx=16618421.719782993
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0005316030226706343, Wx=19045151.370046083
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0008483819338351277, Wx=19661037.18772439
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0009287771482044303, Wx=13427248.463150758
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.00022636477214956768, Wx=20558373.580821294
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0007642285670481258, Wx=16915543.96831584
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0006842295571339797, Wx=12533446.224609545
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0010350780026206624, Wx=18141335.517104954
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=9.00678723171262e-05, Wx=12484743.791004727
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0007451060655557178, Wx=13012100.496866893
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.00020062442669289298, Wx=19009180.421215832
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.00018544831339931787, Wx=16934749.53738116
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.000934740922599456, Wx=12701563.67831876
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0009200380233213448, Wx=13719094.951134333
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.00033937165421181015, Wx=15489055.61205394
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0007747605891447764, Wx=12623030.053159233
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.0006004093546703417, Wx=14919682.894148089
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.00010411669200952869, Wx=18445127.17587295
# Added task 0 to DAG with dependencies [] and data 10
# MEC computation model: transmission_time=0.0003433512472866671, Wx=15184024.650980985
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0007349034136031789, Wx=12542330.775148032
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00022727709662429078, Wx=15872747.945875391
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00021517866157544068, Wx=15587642.925223354
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0010957192728766182, Wx=15598909.579123687
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=0.00013833845597732713, Wx=19609820.144269902
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.002417728969136593, Wx=12168054.482680462
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.0009235784894400861, Wx=14552480.584569236
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.0002518057702808749, Wx=19205140.19171399
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.00011230445991758912, Wx=17715515.969323393
# Added task 0 to DAG with dependencies [] and data 15
# MEC computation model: transmission_time=0.00033025689881922366, Wx=16776652.07652997
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=2.6780111748821972e-05, Wx=18625006.59502291
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.00225759996664064, Wx=15125419.755413003
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.000670454970598135, Wx=19906993.401382513
# Added task 0 to DAG with dependencies [] and data 40
# MEC computation model: transmission_time=0.0018472280964077165, Wx=12058838.62722646
# Added task 0 to DAG with dependencies [] and data 5
# MEC computation model: transmission_time=4.231290375704428e-05, Wx=19895554.05606066
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0011824814239980534, Wx=11945893.26330534
# Added task 0 to DAG with dependencies [] and data 45
# MEC computation model: transmission_time=0.0005222542999529768, Wx=21238096.498695485
# Added task 0 to DAG with dependencies [] and data 25
# MEC computation model: transmission_time=0.001229573519129301, Wx=12499782.311339421
# Added task 0 to DAG with dependencies [] and data 30
# MEC computation model: transmission_time=0.0006616302679547044, Wx=18076541.35380788
# Added task 0 to DAG with dependencies [] and data 35
# MEC computation model: transmission_time=0.000899364947775757, Wx=18562868.905006118
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0003768418511797576, Wx=13821046.777454497
# Added task 0 to DAG with dependencies [] and data 20
# MEC computation model: transmission_time=0.0004997564319522903, Wx=12967859.315798253
# ...
# MEC computation model: edge_time=0.008138175955437357, ATm=520.8432611479908, DTm=520.8440466658103
# Task 0.011002715181034975: total_time=0.010176047386472332, energy_consumed=520.8440466658103, Qn=0.9077878189943195, trans_rate=19575827.396107275
# MEC computation model: edge_time=0.005870327193412267, ATm=375.70094037838504, DTm=375.701728976692
# Task 0.01101070689967417: total_time=0.007916190343086438, energy_consumed=375.701728976692, Qn=0.9822246807278041, trans_rate=14065512.494215634
# MEC computation model: edge_time=0.0072177358086787154, ATm=461.9350917554378, DTm=461.9358843647622
# Task 0.011021112695363556: total_time=0.009274004754042272, energy_consumed=461.9358843647622, Qn=0.9057550818734075, trans_rate=17206434.96827428
# MEC computation model: edge_time=0.007846711092197691, ATm=502.1895099006522, DTm=502.1903030960429
# Task 0.011022633129012853: total_time=0.009904500471210545, energy_consumed=502.1903030960429, Qn=0.8752758342495028, trans_rate=18692034.496865943
# MEC computation model: edge_time=0.005373086808649778, ATm=343.8775557535858, DTm=343.8783509386735
# Task 0.011027795006481923: total_time=0.0074360380651317, energy_consumed=343.8783509386735, Qn=0.5993508597012389, trans_rate=12767466.387757286
# MEC computation model: edge_time=0.005350311078905781, ATm=342.41990904996993, DTm=342.4207045521602
# Task 0.011028617666579916: total_time=0.007414084995485697, energy_consumed=342.4207045521602, Qn=0.596810298997769, trans_rate=12708279.1782439
# MEC computation model: edge_time=0.007810146197207032, ATm=499.8493566212501, DTm=499.850158822378
# Task 0.011045996742245889: total_time=0.009891299189452921, energy_consumed=499.850158822378, Qn=0.8711971357233117, trans_rate=18396067.23826216
# MEC computation model: edge_time=0.005860401179623199, ATm=375.0656754958847, DTm=375.0664789204949
# Task 0.011049170826275065: total_time=0.007944728255898264, energy_consumed=375.0664789204949, Qn=0.653709238337054, trans_rate=13782604.990286898
# MEC computation model: edge_time=0.0058413848552303005, ATm=373.84863073473923, DTm=373.84944096938756
# Task 0.01106683813039907: total_time=0.007943379235629372, energy_consumed=373.84944096938756, Qn=0.8377560352599199, trans_rate=13622414.861540556
# MEC computation model: edge_time=0.008656541427108897, ATm=554.0186513349694, DTm=554.0194648836488
# Task 0.011075435731902764: total_time=0.010767133409011661, energy_consumed=554.0194648836488, Qn=0.9656098498212974, trans_rate=20105272.344121855
# MEC computation model: edge_time=0.005575336141619749, ATm=356.82151306366393, DTm=356.8223327294134
# Task 0.011091305266721639: total_time=0.007701797658341388, energy_consumed=356.8223327294134, Qn=0.799600029274317, trans_rate=12852374.1956646
# MEC computation model: edge_time=0.006611653381249713, ATm=423.1458163999816, DTm=423.14663985981394
# Task 0.01110114826830505: total_time=0.008747957899554763, energy_consumed=423.14663985981394, Qn=0.737509048191689, trans_rate=15171088.820275288
# MEC computation model: edge_time=0.006861493004138685, ATm=439.1355522648758, DTm=439.1363775911815
# Task 0.011105990466099756: total_time=0.00900263972023844, energy_consumed=439.1363775911815, Qn=0.9840572599773127, trans_rate=15708764.549025783
# MEC computation model: edge_time=0.005364701835335377, ATm=343.3409174614641, DTm=343.34174364029786
# Task 0.011108202182587238: total_time=0.007508060267922615, energy_consumed=343.34174364029786, Qn=0.7693914116783509, trans_rate=12269323.51422259
# MEC computation model: edge_time=0.00555736263160921, ATm=355.6712084229894, DTm=355.6720356766054
# Task 0.0111109904934677: total_time=0.0077035093750769095, energy_consumed=355.6720356766054, Qn=0.9298593684261162, trans_rate=12693434.765016044
# MEC computation model: edge_time=0.005456939730350654, ATm=349.24414274244185, DTm=349.24497428258996
# Task 0.011122111057682545: total_time=0.007614207038033199, energy_consumed=349.24497428258996, Qn=0.7826199277141556, trans_rate=12399809.919373613
# MEC computation model: edge_time=0.0053017201067530285, ATm=339.31008683219386, DTm=339.3109230306415
# Task 0.011134196099262006: total_time=0.0074710724560150335, energy_consumed=339.3109230306415, Qn=0.887085194332533, trans_rate=11979992.12140531
# MEC computation model: edge_time=0.005477271816542666, ATm=350.5453962587306, DTm=350.54623872621505
# Task 0.011150459881845829: total_time=0.007662887948388495, energy_consumed=350.54623872621505, Qn=0.9164585523104067, trans_rate=12284577.90849289
# MEC computation model: edge_time=0.006856920593358759, ATm=438.8429179749605, DTm=438.84377113444475
# Task 0.011178198171588305: total_time=0.009070275014947064, energy_consumed=438.84377113444475, Qn=0.8604763097548246, trans_rate=15186160.662727294
# MEC computation model: edge_time=0.007029118274180805, ATm=449.86356954757144, DTm=449.8644238902401
# Task 0.011181267710814907: total_time=0.009245542234995711, energy_consumed=449.8644238902401, Qn=0.8820854304854343, trans_rate=15545970.77883455
# MEC computation model: edge_time=0.0069660180155901984, ATm=445.82515299777265, DTm=445.82602321214245
# Task 0.01122244371664064: total_time=0.009223617982230838, energy_consumed=445.82602321214245, Qn=0.7770373036998217, trans_rate=15125419.755413003
# MEC computation model: edge_time=0.006598017484696872, ATm=422.27311902059984, DTm=422.2739942753747
# Task 0.011235520055999561: total_time=0.008868693790696434, energy_consumed=422.2739942753747, Qn=0.8279865078835291, trans_rate=14243872.135690745
# MEC computation model: edge_time=0.0062575130690610764, ATm=400.4808364199089, DTm=400.4817214705379
# Task 0.011260933472137346: total_time=0.008553602791198423, energy_consumed=400.4817214705379, Qn=0.7852565419998213, trans_rate=13359270.491971295
# MEC computation model: edge_time=0.00602680375044112, ATm=385.7154400282317, DTm=385.7163282185298
# Task 0.011269078725883952: total_time=0.008331038726325072, energy_consumed=385.7163282185298, Qn=0.6722709194391837, trans_rate=12821242.602692414
# MEC computation model: edge_time=0.00686786286479525, ATm=439.54322334689596, DTm=439.54411976324343
# Task 0.011290419592418922: total_time=0.009193438707214173, energy_consumed=439.54411976324343, Qn=0.7660884067048296, trans_rate=14476412.173362412
# MEC computation model: edge_time=0.007890178968107679, ATm=504.9714539588914, DTm=504.972355640008
# Task 0.011304078000111156: total_time=0.010229413218218835, energy_consumed=504.972355640008, Qn=0.9901401058017479, trans_rate=16534191.854040649
# MEC computation model: edge_time=0.006239484517190273, ATm=399.32700910017746, DTm=399.3279115507748
# Task 0.01130607426649654: total_time=0.008580715033686813, energy_consumed=399.3279115507748, Qn=0.6959947871027058, trans_rate=13063945.733702628
# MEC computation model: edge_time=0.0071156102873000705, ATm=455.3990583872045, DTm=455.39996395136467
# Task 0.011314151792666604: total_time=0.009464918329966675, energy_consumed=455.39996395136467, Qn=0.8929393301709893, trans_rate=14847113.256894525
# MEC computation model: edge_time=0.0059509369535637995, ATm=380.85996502808314, DTm=380.86088864438324
# Task 0.011360984518006958: total_time=0.00834707772157076, energy_consumed=380.86088864438324, Qn=0.9957123268708057, trans_rate=12174267.875153659
# MEC computation model: edge_time=0.00589837444803422, ATm=377.49596467419, DTm=377.4968909555832
# Task 0.011367898577592763: total_time=0.008301429275626982, energy_consumed=377.4968909555832, Qn=0.6579450364691766, trans_rate=12032018.538846979
# MEC computation model: edge_time=0.006001487795445023, ATm=384.09521890848146, DTm=384.0961508461685
# Task 0.011382572719136593: total_time=0.008419216764581617, energy_consumed=384.0961508461685, Qn=0.8607175773859529, trans_rate=12168054.482680462
# MEC computation model: edge_time=0.006820299834613467, ATm=436.49918941526187, DTm=436.50012170724267
# Task 0.011383491864522722: total_time=0.009238947949136189, energy_consumed=436.50012170724267, Qn=0.9781494440678137, trans_rate=13822946.019220322
# MEC computation model: edge_time=0.005891665683623999, ATm=377.06660375193593, DTm=377.0675371745648
# Task 0.01138642510849405: total_time=0.008313247042118048, energy_consumed=377.0675371745648, Qn=0.8449671792760469, trans_rate=11926386.051044062
# MEC computation model: edge_time=0.00790395672174201, ATm=505.8532301914886, DTm=505.8541713447596
# Task 0.011406480738579559: total_time=0.010345593710321569, energy_consumed=505.8541713447596, Qn=0.9918690788068404, trans_rate=15868405.529616565
# MEC computation model: edge_time=0.006770258573226802, ATm=433.29654868651534, DTm=433.297495426273
# Task 0.01142097377899473: total_time=0.009226388602221535, energy_consumed=433.297495426273, Qn=0.7552009563163666, trans_rate=13512127.466315327
# MEC computation model: edge_time=0.006580686377002087, ATm=421.1639281281336, DTm=421.1648787993131
# Task 0.011431173079549758: total_time=0.009047015706551845, energy_consumed=421.1648787993131, Qn=0.9437847128921761, trans_rate=13079464.355160033
# MEC computation model: edge_time=0.006612375966988913, ATm=423.1920618872904, DTm=423.1930205460839
# Task 0.011451895372519358: total_time=0.00909942758950827, energy_consumed=423.1930205460839, Qn=0.8297883566417459, trans_rate=13032945.27054631
# MEC computation model: edge_time=0.007235173248320697, ATm=463.0510878925246, DTm=463.05205792689225
# Task 0.01148140706134727: total_time=0.009751736559667967, energy_consumed=463.05205792689225, Qn=0.8070607196383871, trans_rate=14093241.910928277
# MEC computation model: edge_time=0.007834563019114013, ATm=501.4120332232969, DTm=501.41300553356945
# Task 0.011487311448959953: total_time=0.010357030718073965, energy_consumed=501.41300553356945, Qn=0.8739207550732844, trans_rate=15225059.451808337
# MEC computation model: edge_time=0.006183341242982092, ATm=395.7338395508539, DTm=395.7348149162155
# Task 0.011495237276424148: total_time=0.008713734769406239, energy_consumed=395.7348149162155, Qn=0.7759487050016743, trans_rate=11978570.120656885
# MEC computation model: edge_time=0.007165355441991988, ATm=458.5827482874872, DTm=458.58373041489574
# Task 0.011512780076591081: total_time=0.00971329176858307, energy_consumed=458.58373041489574, Qn=0.8991818593872299, trans_rate=13785388.20446386
# MEC computation model: edge_time=0.008789445878678104, ATm=562.5245362353986, DTm=562.5255188655397
# Task 0.011514084317285221: total_time=0.011338686445963326, energy_consumed=562.5255188655397, Qn=0.9804349215431785, trans_rate=16901315.460788887
# MEC computation model: edge_time=0.007300652040314757, ATm=467.24173058014446, DTm=467.2427266676989
# Task 0.011548996928466202: total_time=0.009884805218780959, energy_consumed=467.2427266676989, Qn=0.9161602560394989, trans_rate=13848834.620084029
# MEC computation model: edge_time=0.006456753816121669, ATm=413.2322442317868, DTm=413.23324045159734
# Task 0.01154934004095776: total_time=0.00904125010707943, energy_consumed=413.23324045159734, Qn=0.9260106313317352, trans_rate=12246391.728760155
# MEC computation model: edge_time=0.006947911888010917, ATm=444.6663608326986, DTm=444.66738872599103
# Task 0.011631510657906748: total_time=0.009614578795917664, energy_consumed=444.66738872599103, Qn=0.8718948251621542, trans_rate=12771895.697551312
# MEC computation model: edge_time=0.006885635494947381, ATm=440.68067167663236, DTm=440.68170847945606
# Task 0.011654624683903056: total_time=0.009575416428850438, energy_consumed=440.68170847945606, Qn=0.8640797483855538, trans_rate=12548648.384659566
# MEC computation model: edge_time=0.008375840117067579, ATm=536.053767492325, DTm=536.0548054930231
# Task 0.011657732333245026: total_time=0.011068728700312603, energy_consumed=536.0548054930231, Qn=0.9342985054332463, trans_rate=15246839.414377322
# MEC computation model: edge_time=0.007602952681159564, ATm=486.58897159421207, DTm=486.5900177495292
# Task 0.01167888788782398: total_time=0.010316996818983546, energy_consumed=486.5900177495292, Qn=0.9540960227337493, trans_rate=13732044.873049954
# MEC computation model: edge_time=0.007659904565942412, ATm=490.2338922203144, DTm=490.2349483366248
# Task 0.011704729725219465: total_time=0.010399790541161878, energy_consumed=490.2349483366248, Qn=0.9612429259221851, trans_rate=13704421.327543642
# MEC computation model: edge_time=0.0074921630158327306, ATm=479.49843301329474, DTm=479.49949329449885
# Task 0.011715534722353869: total_time=0.0102428539881866, energy_consumed=479.49949329449885, Qn=0.835727116363041, trans_rate=13351659.514798071
# MEC computation model: edge_time=0.007607408316421929, ATm=486.8741322510034, DTm=486.8752018506391
# Task 0.011739709559777411: total_time=0.01038227412619934, energy_consumed=486.8752018506391, Qn=0.9546551612764773, trans_rate=13438926.345902741
# MEC computation model: edge_time=0.007486352170326303, ATm=479.1265389008834, DTm=479.12762292935685
# Task 0.01177714234036684: total_time=0.010298650760693143, energy_consumed=479.12762292935685, Qn=0.8350789349035005, trans_rate=13049042.8300199
# MEC computation model: edge_time=0.007990962922670495, ATm=511.4216270509116, DTm=511.4227124127958
# Task 0.011780601612313927: total_time=0.010806720784984422, energy_consumed=511.4227124127958, Qn=0.8913666702412403, trans_rate=13911489.833733635
# MEC computation model: edge_time=0.007489717552258357, ATm=479.34192334453485, DTm=479.3430160217836
# Task 0.011799579886262512: total_time=0.01032445368852087, energy_consumed=479.3430160217836, Qn=0.9398861242049703, trans_rate=12951576.42967187
# MEC computation model: edge_time=0.008628277049427526, ATm=552.2097311633617, DTm=552.2108406355854
# Task 0.011843151144711107: total_time=0.011506584444138634, energy_consumed=552.2108406355854, Qn=0.9624570477792795, trans_rate=14694565.219199955
# MEC computation model: edge_time=0.00725526811941929, ATm=464.33715964283454, DTm=464.33829059644506
# Task 0.011898880375948422: total_time=0.010189304745367713, energy_consumed=464.33829059644506, Qn=0.8093022390289055, trans_rate=12121539.14049338
# MEC computation model: edge_time=0.007369173768086597, ATm=471.62712115754215, DTm=471.62826893576704
# Task 0.011942528527659766: total_time=0.010346858545746362, energy_consumed=471.62826893576704, Qn=0.9247590610932199, trans_rate=12131371.693529008
# MEC computation model: edge_time=0.00849578443506454, ATm=543.7302038441305, DTm=543.7313622106218
# Task 0.011969997701589134: total_time=0.011500938386653673, energy_consumed=543.7313622106218, Qn=0.9476779151967417, trans_rate=13858192.559701238
# MEC computation model: edge_time=0.007704469720254652, ATm=493.0860620962977, DTm=493.08723302393213
# Task 0.012002585115987896: total_time=0.01074221108624255, energy_consumed=493.08723302393213, Qn=0.8594092585556388, trans_rate=12432595.103546191
# MEC computation model: edge_time=0.007569857886044866, ATm=484.4709047068714, DTm=484.4721002905703
# Task 0.012066550424251355: total_time=0.01067156456029622, energy_consumed=484.4721002905703, Qn=0.8443937336938936, trans_rate=11963460.893405184
# MEC computation model: edge_time=0.008669111059330312, ATm=554.82310779714, DTm=554.8243372854317
# Task 0.012154509219569967: total_time=0.01185877652890028, energy_consumed=554.8243372854317, Qn=0.9670119525876077, trans_rate=13322915.162456488
# MEC computation model: edge_time=0.008759626786786729, ATm=560.6161143543507, DTm=560.6173747956276
# Task 0.012234810649674941: total_time=0.01202959368646167, energy_consumed=560.6173747956276, Qn=0.9771086960424412, trans_rate=13131431.696853286
#    num_devices  task_data  completion_time  energy_consumed  weighted_waste  \
# 0           50          5         0.000370        16.922573       16.922573
# 1           50          5         0.001020        47.619677       47.619677
# 2           50         10         0.002477       117.089966      117.089966
# 3           50         15         0.001322        62.283417       62.283417
# 4           50         20         0.002029       105.698567      105.698567
#
#    transmission_rate
# 0       1.222053e+07
# 1       1.322449e+07
# 2       1.384351e+07
# 3       1.367039e+07
# 4       2.144481e+07

# %%
# Compute the metrics
mean_completion_by_devices = df_logs.groupby('num_devices')['completion_time'].sum()
mean_completion_by_task_data = df_logs.groupby('task_data')['completion_time'].mean()
mean_completion_by_transmission_rate = df_logs.groupby('transmission_rate')['completion_time'].mean()

energy_by_devices = df_logs.groupby('num_devices')['energy_consumed'].mean()
energy_by_task_data = df_logs.groupby('task_data')['energy_consumed'].sum()
energy_by_transmission_rate = df_logs.groupby('transmission_rate')['energy_consumed'].sum()

# %%
# Output the results
print("Mean Completion Times by Number of Devices:")
print(mean_completion_by_devices)
# Out:
# Mean Completion Times by Number of Devices:
# num_devices
# 50     0.122342
# 100    0.361708
# 150    0.550638
# 200    0.599520
# 250    0.836582
# 300    0.904568
# Name: completion_time, dtype: float64

# %%
print("\nMean Completion Times by Task Data:")
print(mean_completion_by_task_data)
# Out:
# Mean Completion Times by Task Data:
# task_data
# 5     0.000675
# 10    0.001384
# 15    0.002062
# 20    0.002630
# 25    0.003251
# 30    0.003924
# 35    0.004383
# 40    0.005235
# 45    0.005388
# Name: completion_time, dtype: float64

# %%
print("\nMean Completion Times by Transmission Rate:")
print(mean_completion_by_transmission_rate)
# Out:
# Mean Completion Times by Transmission Rate:
# transmission_rate
# 1.191830e+07    0.005158
# 1.191834e+07    0.001434
# 1.191848e+07    0.003527
# 1.192256e+07    0.001189
# 1.192554e+07    0.004001
#                   ...
# 2.505706e+07    0.003817
# 2.514020e+07    0.005442
# 2.514428e+07    0.002591
# 2.517742e+07    0.004345
# 2.518024e+07    0.001270
# Name: completion_time, Length: 1050, dtype: float64

# %%
print("\nTotal Energy Consumption by Number of Devices:")
print(energy_by_devices)
# Out:
# Total Energy Consumption by Number of Devices:
# num_devices
# 50      5897.085399
# 100    17429.576879
# 150    26893.372695
# 200    29193.854406
# 250    40427.125903
# 300    44196.641025
# Name: energy_consumed, dtype: float64

# %%
print("\nTotal Energy Consumption by Task Data:")
print(energy_by_task_data)
# Out:
# Total Energy Consumption by Task Data:
# task_data
# 5      3893.934354
# 10     8255.786454
# 15    10821.949978
# 20    14343.833129
# 25    16944.767379
# 30    24544.647492
# 35    25520.080849
# 40    29661.661372
# 45    30050.995301
# Name: energy_consumed, dtype: float64

# %%
print("\nTotal Energy Consumption by Transmission Rate:")
print(energy_by_transmission_rate)
# Out:
# Total Energy Consumption by Transmission Rate:
# transmission_rate
# 500.0     39077.189239
# 1000.0    39790.168873
# 1500.0    42611.550284
# 2000.0    29507.904894
# 2500.0    31778.786233
# 3000.0    37075.837815
# Name: energy_consumed, dtype: float64
